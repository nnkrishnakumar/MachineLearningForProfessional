# %%
import pandas as pd

# %%
df=pd.DataFrame({"feature1":[1,3.5,2.4,4,6],"target":[20000,35000,34000,34455,70000]})
df
# Out:
#    feature1  target
# 0       1.0   20000
# 1       3.5   35000
# 2       2.4   34000
# 3       4.0   34455
# 4       6.0   70000

# %%
X=df.iloc[:,:-1].values
X
# Out:
# array([[1. ],
#        [3.5],
#        [2.4],
#        [4. ],
#        [6. ]])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
feature_expansion=PolynomialFeatures(degree=10)

# %%
feature_expansion.fit_transform(X)
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 3.50000000e+00, 1.22500000e+01, 4.28750000e+01,
#         1.50062500e+02, 5.25218750e+02, 1.83826562e+03, 6.43392969e+03,
#         2.25187539e+04, 7.88156387e+04, 2.75854735e+05],
#        [1.00000000e+00, 2.40000000e+00, 5.76000000e+00, 1.38240000e+01,
#         3.31776000e+01, 7.96262400e+01, 1.91102976e+02, 4.58647142e+02,
#         1.10075314e+03, 2.64180754e+03, 6.34033810e+03],
#        [1.00000000e+00, 4.00000000e+00, 1.60000000e+01, 6.40000000e+01,
#         2.56000000e+02, 1.02400000e+03, 4.09600000e+03, 1.63840000e+04,
#         6.55360000e+04, 2.62144000e+05, 1.04857600e+06],
#        [1.00000000e+00, 6.00000000e+00, 3.60000000e+01, 2.16000000e+02,
#         1.29600000e+03, 7.77600000e+03, 4.66560000e+04, 2.79936000e+05,
# ...

# %%
salary=pd.read_csv(r"C:\Users\aimar\OneDrive\Desktop\Youtube\MachineLearningForProfessional\archive (2)\Salary Data.csv")

# %%
salary
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
salary_1=salary.iloc[:,-2:]

# %%
salary_1.dropna(inplace=True)

# %%
X=salary_1.iloc[:,:-1].values

# %%
X
# Out:
# array([[ 5. ],
#        [ 3. ],
#        [15. ],
#        [ 7. ],
#        [20. ],
#        [ 2. ],
#        [12. ],
#        [ 4. ],
#        [ 1. ],
#        [10. ],
#        [ 3. ],
#        [18. ],
#        [ 6. ],
#        [14. ],
#        [ 2. ],
#        [16. ],
#        [ 7. ],
#        [12. ],
#        [ 0. ],
#        [22. ],
#        [ 5. ],
#        [19. ],
#        [ 2. ],
#        [ 9. ],
#        [13. ],
#        [ 3. ],
#        [11. ],
#        [ 1. ],
#        [15. ],
#        [ 6. ],
#        [25. ],
#        [ 4. ],
#        [ 3. ],
#        [10. ],
#        [20. ],
#        [ 2. ],
#        [ 7. ],
#        [14. ],
#        [ 1. ],
#        [21. ],
#        [ 5. ],
#        [18. ],
#        [ 3. ],
#        [ 8. ],
#        [13. ],
#        [ 2. ],
#        [ 5. ],
#        [16. ],
#        [11. ],
#        [ 0. ],
#        [22. ],
#        [ 7. ],
#        [12. ],
#        [19. ],
#        [ 3. ],
#        [ 9. ],
#        [ 2. ],
#        [17. ],
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
salaryfeature=PolynomialFeatures(degree=3)

# %%
X_feature=salaryfeature.fit_transform(X)

# %%
X_feature
# Out:
# array([[1.000e+00, 5.000e+00, 2.500e+01, 1.250e+02],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01],
#        [1.000e+00, 1.500e+01, 2.250e+02, 3.375e+03],
#        ...,
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00],
#        [1.000e+00, 7.000e+00, 4.900e+01, 3.430e+02],
#        [1.000e+00, 1.500e+01, 2.250e+02, 3.375e+03]])

# %%
y=salary_1.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_feature,y)
# Out:
# LinearRegression()

# %%
sample=[[5]]
sample_poly=salaryfeature.transform(sample)
sample_poly
# Out:
# array([[  1.,   5.,  25., 125.]])

# %%
model.predict(sample_poly)
# Out:
# array([66828.06672277])
