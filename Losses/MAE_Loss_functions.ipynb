# %%
import pandas as pd         # to read dataset
import numpy as np          # to covert dataset into feature and target 
from matplotlib import pyplot as plt
import seaborn as sn        # to plot the graph 
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/home/new_krishna/Desktop/training /MachineLearningForProfessional/Machine_Learning/archive (2)/Salary Data.csv")

# %%
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
df1=df.iloc[:,-2:].dropna()

# %%
df1
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [373 rows x 2 columns]

# %%
df1['Years of Experience']
# Out:
# 0       5.0
# 1       3.0
# 2      15.0
# 3       7.0
# 4      20.0
#        ...
# 370     8.0
# 371    19.0
# 372     2.0
# 373     7.0
# 374    15.0
# Name: Years of Experience, Length: 373, dtype: float64

# %%
# 1st approch to convert a list into 2D array
cont=[]
for i in df1['Years of Experience']:
    cont.append([i])

# %%
# 2st approch to convert a list into 2D array
cont=np.array([[i] for i in df1['Years of Experience']])

# %%
cont
# Out:
# array([[ 5. ],
#        [ 3. ],
#        [15. ],
#        [ 7. ],
#        [20. ],
#        [ 2. ],
#        [12. ],
#        [ 4. ],
#        [ 1. ],
#        [10. ],
#        [ 3. ],
#        [18. ],
#        [ 6. ],
#        [14. ],
#        [ 2. ],
#        [16. ],
#        [ 7. ],
#        [12. ],
#        [ 0. ],
#        [22. ],
#        [ 5. ],
#        [19. ],
#        [ 2. ],
#        [ 9. ],
#        [13. ],
#        [ 3. ],
#        [11. ],
#        [ 1. ],
#        [15. ],
#        [ 6. ],
#        [25. ],
#        [ 4. ],
#        [ 3. ],
#        [10. ],
#        [20. ],
#        [ 2. ],
#        [ 7. ],
#        [14. ],
#        [ 1. ],
#        [21. ],
#        [ 5. ],
#        [18. ],
#        [ 3. ],
#        [ 8. ],
#        [13. ],
#        [ 2. ],
#        [ 5. ],
#        [16. ],
#        [11. ],
#        [ 0. ],
#        [22. ],
#        [ 7. ],
#        [12. ],
#        [19. ],
#        [ 3. ],
#        [ 9. ],
#        [ 2. ],
#        [17. ],
# ...

# %%
df1.iloc[:,0:1]
# Out:
#      Years of Experience
# 0                    5.0
# 1                    3.0
# 2                   15.0
# 3                    7.0
# 4                   20.0
# ..                   ...
# 370                  8.0
# 371                 19.0
# 372                  2.0
# 373                  7.0
# 374                 15.0
#
# [373 rows x 1 columns]

# %%
# 3rd approch to covert data into feature using pandas
X= df1.iloc[:,0:1].values

# %%
X
# Out:
# array([[ 5. ],
#        [ 3. ],
#        [15. ],
#        [ 7. ],
#        [20. ],
#        [ 2. ],
#        [12. ],
#        [ 4. ],
#        [ 1. ],
#        [10. ],
#        [ 3. ],
#        [18. ],
#        [ 6. ],
#        [14. ],
#        [ 2. ],
#        [16. ],
#        [ 7. ],
#        [12. ],
#        [ 0. ],
#        [22. ],
#        [ 5. ],
#        [19. ],
#        [ 2. ],
#        [ 9. ],
#        [13. ],
#        [ 3. ],
#        [11. ],
#        [ 1. ],
#        [15. ],
#        [ 6. ],
#        [25. ],
#        [ 4. ],
#        [ 3. ],
#        [10. ],
#        [20. ],
#        [ 2. ],
#        [ 7. ],
#        [14. ],
#        [ 1. ],
#        [21. ],
#        [ 5. ],
#        [18. ],
#        [ 3. ],
#        [ 8. ],
#        [13. ],
#        [ 2. ],
#        [ 5. ],
#        [16. ],
#        [11. ],
#        [ 0. ],
#        [22. ],
#        [ 7. ],
#        [12. ],
#        [19. ],
#        [ 3. ],
#        [ 9. ],
#        [ 2. ],
#        [17. ],
# ...

# %%
# coverting target which salary into 1D array(vector)
y=df1.Salary.values

# %%
y
# Out:
# array([ 90000.,  65000., 150000.,  60000., 200000.,  55000., 120000.,
#         80000.,  45000., 110000.,  75000., 140000.,  65000., 130000.,
#         40000., 125000.,  90000., 115000.,  35000., 180000.,  80000.,
#        190000.,  50000.,  60000., 140000.,  45000., 110000.,  40000.,
#        140000.,  90000., 250000.,  55000.,  75000.,  65000., 170000.,
#         45000.,  60000., 115000.,  40000., 160000.,  80000., 190000.,
#         60000.,  45000., 130000.,  40000.,  75000., 180000., 120000.,
#         35000., 130000.,  85000.,  60000., 200000.,  50000.,  95000.,
#         65000., 140000.,  55000., 105000., 170000.,  50000.,  80000.,
#        180000.,  35000.,  90000., 120000.,  45000.,  90000., 150000.,
#         65000.,  70000., 190000.,  40000., 120000.,  95000., 160000.,
#        100000., 180000.,  55000.,  70000.,  80000.,  30000., 250000.,
#         40000.,  95000.,  45000.,  80000., 135000.,  55000., 120000.,
# ...

# %%
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[3]])
# Out:
# array([52454.7484605])

# %%
sn.scatterplot(x=X.flatten(),y=y)   # always keep parameter like x= and y= into 1 D array
plt.show()

# %%
X_predict_salary=model.predict(X)

# %%
X_predict_salary
# Out:
# array([ 66143.76948947,  52454.7484605 , 134588.87463431,  79832.79051843,
#        168811.42720673,  45610.23794601, 114055.34309085,  59299.25897498,
#         38765.72743153, 100366.32206189,  52454.7484605 , 155122.40617776,
#         72988.28000395, 127744.36411982,  45610.23794601, 141433.38514879,
#         79832.79051843, 114055.34309085,  31921.21691704, 182500.4482357 ,
#         66143.76948947, 161966.91669224,  45610.23794601,  93521.8115474 ,
#        120899.85360534,  52454.7484605 , 107210.83257637,  38765.72743153,
#        134588.87463431,  72988.28000395, 203033.97977915,  59299.25897498,
#         52454.7484605 , 100366.32206189, 168811.42720673,  45610.23794601,
#         79832.79051843, 127744.36411982,  38765.72743153, 175655.93772121,
#         66143.76948947, 155122.40617776,  52454.7484605 ,  86677.30103292,
#        120899.85360534,  45610.23794601,  66143.76948947, 141433.38514879,
# ...

# %%
X
# Out:
# array([[ 5. ],
#        [ 3. ],
#        [15. ],
#        [ 7. ],
#        [20. ],
#        [ 2. ],
#        [12. ],
#        [ 4. ],
#        [ 1. ],
#        [10. ],
#        [ 3. ],
#        [18. ],
#        [ 6. ],
#        [14. ],
#        [ 2. ],
#        [16. ],
#        [ 7. ],
#        [12. ],
#        [ 0. ],
#        [22. ],
#        [ 5. ],
#        [19. ],
#        [ 2. ],
#        [ 9. ],
#        [13. ],
#        [ 3. ],
#        [11. ],
#        [ 1. ],
#        [15. ],
#        [ 6. ],
#        [25. ],
#        [ 4. ],
#        [ 3. ],
#        [10. ],
#        [20. ],
#        [ 2. ],
#        [ 7. ],
#        [14. ],
#        [ 1. ],
#        [21. ],
#        [ 5. ],
#        [18. ],
#        [ 3. ],
#        [ 8. ],
#        [13. ],
#        [ 2. ],
#        [ 5. ],
#        [16. ],
#        [11. ],
#        [ 0. ],
#        [22. ],
#        [ 7. ],
#        [12. ],
#        [19. ],
#        [ 3. ],
#        [ 9. ],
#        [ 2. ],
#        [17. ],
# ...

# %%
# ploting a line chart between X and X_predict_salary
sn.lineplot(x=X.flatten(),y=X_predict_salary)
# Out:
# <Axes: >

# %%
sn.scatterplot(x=X.flatten(),y=y)   # always keep parameter like x= and y= into 1 D array
sn.scatterplot(x=X.flatten(),y=X_predict_salary,color="red") 
plt.show()

# %%
# absolute loss 
a=-8
b= 3

# %%
abs(a)+b
# Out:
# 11

# %% [markdown]
# # Losses
#
# mae : mean abosolute error
#
# mse: mean square error
#
# rmse: root mean square error
#
# ols : ordinary list square

# %%
a=-8
c= 0
b= 3

# %%
(abs(a)+3)/2
# Out:
# 5.5

# %%
df1
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [373 rows x 2 columns]

# %%
y
# Out:
# array([ 90000.,  65000., 150000.,  60000., 200000.,  55000., 120000.,
#         80000.,  45000., 110000.,  75000., 140000.,  65000., 130000.,
#         40000., 125000.,  90000., 115000.,  35000., 180000.,  80000.,
#        190000.,  50000.,  60000., 140000.,  45000., 110000.,  40000.,
#        140000.,  90000., 250000.,  55000.,  75000.,  65000., 170000.,
#         45000.,  60000., 115000.,  40000., 160000.,  80000., 190000.,
#         60000.,  45000., 130000.,  40000.,  75000., 180000., 120000.,
#         35000., 130000.,  85000.,  60000., 200000.,  50000.,  95000.,
#         65000., 140000.,  55000., 105000., 170000.,  50000.,  80000.,
#        180000.,  35000.,  90000., 120000.,  45000.,  90000., 150000.,
#         65000.,  70000., 190000.,  40000., 120000.,  95000., 160000.,
#        100000., 180000.,  55000.,  70000.,  80000.,  30000., 250000.,
#         40000.,  95000.,  45000.,  80000., 135000.,  55000., 120000.,
# ...

# %%
X_predict_salary
# Out:
# array([ 66143.76948947,  52454.7484605 , 134588.87463431,  79832.79051843,
#        168811.42720673,  45610.23794601, 114055.34309085,  59299.25897498,
#         38765.72743153, 100366.32206189,  52454.7484605 , 155122.40617776,
#         72988.28000395, 127744.36411982,  45610.23794601, 141433.38514879,
#         79832.79051843, 114055.34309085,  31921.21691704, 182500.4482357 ,
#         66143.76948947, 161966.91669224,  45610.23794601,  93521.8115474 ,
#        120899.85360534,  52454.7484605 , 107210.83257637,  38765.72743153,
#        134588.87463431,  72988.28000395, 203033.97977915,  59299.25897498,
#         52454.7484605 , 100366.32206189, 168811.42720673,  45610.23794601,
#         79832.79051843, 127744.36411982,  38765.72743153, 175655.93772121,
#         66143.76948947, 155122.40617776,  52454.7484605 ,  86677.30103292,
#        120899.85360534,  45610.23794601,  66143.76948947, 141433.38514879,
# ...

# %%
y[0]
# Out:
# 90000.0

# %%
X_predict_salary[0]
# Out:
# 66143.76948946505

# %%
y[0]-X_predict_salary[0]
# Out:
# 23856.23051053495

# %%
# numpy contain a concept called broadcasting then number of dimension must be same

# %%
a=np.array([10,20,30,40])
b=np.array([1,2,1,1])

# %%
a+b    # broadcasting on addition operation
# Out:
# array([11, 22, 31, 41])

# %%
a-b
# Out:
# array([ 9, 18, 29, 39])

# %%
a.shape
# Out:
# (4,)

# %%
y.shape
# Out:
# (373,)

# %%
X_predict_salary.shape
# Out:
# (373,)

# %%
# error / lossresidual
X_predict_salary-y
# Out:
# array([-23856.23051053, -12545.2515395 , -15411.12536569,  19832.79051843,
#        -31188.57279327,  -9389.76205399,  -5944.65690915, -20700.74102502,
#         -6234.27256847,  -9633.67793811, -22545.2515395 ,  15122.40617776,
#          7988.28000395,  -2255.63588018,   5610.23794601,  16433.38514879,
#        -10167.20948157,   -944.65690915,  -3078.78308296,   2500.4482357 ,
#        -13856.23051053, -28033.08330776,  -4389.76205399,  33521.8115474 ,
#        -19100.14639466,   7454.7484605 ,  -2789.16742363,  -1234.27256847,
#         -5411.12536569, -17011.71999605, -46966.02022085,   4299.25897498,
#        -22545.2515395 ,  35366.32206189,  -1188.57279327,    610.23794601,
#         19832.79051843,  12744.36411982,  -1234.27256847,  15655.93772121,
#        -13856.23051053, -34877.59382224,  -7545.2515395 ,  41677.30103292,
#         -9100.14639466,   5610.23794601,  -8856.23051053, -38566.61485121,
# ...

# %%
# residual of each datapoint
abs(y-X_predict_salary)
# Out:
# array([23856.23051053, 12545.2515395 , 15411.12536569, 19832.79051843,
#        31188.57279327,  9389.76205399,  5944.65690915, 20700.74102502,
#         6234.27256847,  9633.67793811, 22545.2515395 , 15122.40617776,
#         7988.28000395,  2255.63588018,  5610.23794601, 16433.38514879,
#        10167.20948157,   944.65690915,  3078.78308296,  2500.4482357 ,
#        13856.23051053, 28033.08330776,  4389.76205399, 33521.8115474 ,
#        19100.14639466,  7454.7484605 ,  2789.16742363,  1234.27256847,
#         5411.12536569, 17011.71999605, 46966.02022085,  4299.25897498,
#        22545.2515395 , 35366.32206189,  1188.57279327,   610.23794601,
#        19832.79051843, 12744.36411982,  1234.27256847, 15655.93772121,
#        13856.23051053, 34877.59382224,  7545.2515395 , 41677.30103292,
#         9100.14639466,  5610.23794601,  8856.23051053, 38566.61485121,
#        12789.16742363,  3078.78308296, 52500.4482357 ,  5167.20948157,
# ...

# %%
# absolute Loss/error
sum(abs(y-X_predict_salary))
# Out:
# 4690377.353792655

# %%
# calculating the mean
print("Mean abosulute error of model on given dataset:",sum(abs(y-X_predict_salary))/(y-X_predict_salary).shape[0])
# Out:
# Mean abosulute error of model on given dataset: 12574.738213921328

# %%
(y-X_predict_salary).shape[0]
# Out:
# 373

# %%
373*12574.738213921328
# Out:
# 4690377.353792655

# %%
[62,64,61,55,75]
# Out:
# [62, 64, 61, 55, 75]
