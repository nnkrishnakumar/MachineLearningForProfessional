# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\aimar\OneDrive\Desktop\Youtube\MachineLearningForProfessional\archive (2)\Salary Data.csv")

# %%
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
df1=df.iloc[:,-2:]

# %%
df1
df1.dropna(inplace=True)

# %%
X=df1.iloc[:,:-1].values   # feature X
y=df1.iloc[:,-1].values     # target

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(max_iter=2000)

model.fit(X,y)
# Out:
# LogisticRegression(max_iter=2000)

# %%
model.score(X,y)
# Out:
# 0.289544235924933

# %%
model.predict([[1]])
# Out:
# array([40000.])

# %%
model.predict([[2]])
# Out:
# array([40000.])

# %%
model.predict([[3]])
# Out:
# array([50000.])

# %%
model.predict([[4]])
# Out:
# array([50000.])

# %%
model.predict([[5]])
# Out:
# array([60000.])

# %%
model.predict([[100]])
# Out:
# array([250000.])

# %%
y_pred=model.predict(X)

# %%
y_pred.shape
# Out:
# (373,)

# %%
# df['Years of Experience'].shape
X.flatten().shape
# Out:
# (373,)

# %%
sn.scatterplot(x=X.flatten(),y=y, color='red')
sn.scatterplot(x=X.flatten(),y=y_pred)

plt.xticks([i for i in range(0,26)])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model_linear=LinearRegression()
model_linear.fit(X,y)
# Out:
# LinearRegression()

# %%
model_linear.score(X,y)
# Out:
# 0.865528278393677

# %%
y_pred_linear=model_linear.predict(X)

# %%
sn.scatterplot(x=X.flatten(),y=y, color='red')
sn.scatterplot(x=X.flatten(),y=y_pred_linear)

plt.xticks([i for i in range(0,26)])
plt.show()

# %%
# activation function :

# sigmoid function 

# > it is always play good role with two calss 

# softmax function 

# > it is always play good classificaiton role with more then two class

# %%
df=pd.read_csv(r"C:\Users\aimar\OneDrive\Desktop\Youtube\MachineLearningForProfessional\classification_model\IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X=df.iloc[:,:-1].values

# %%
y=df.iloc[:,-1].values

# %%
Model_sigmoid= LogisticRegression(multi_class='ovr')

# %%
Model_sigmoid.fit(X,y)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
Model_sigmoid.predict([[5.1,3.5,1.4,0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
Model_sigmoid.predict_proba([[5.1,3.5,1.4,0.2]])
# Out:
# array([[8.98656962e-01, 1.01341961e-01, 1.07683291e-06]])

# %%
df.species.value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
Model_softmax= LogisticRegression(multi_class='multinomial')

# %%
Model_softmax.fit(X,y)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
Model_softmax.predict([[5.1,3.5,1.4,0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
Model_softmax.predict_proba([[5.1,3.5,1.4,0.2]])
# Out:
# array([[9.81748306e-01, 1.82516800e-02, 1.43428735e-08]])

# %%
Model_sigmoid.predict_proba([[5.1,3.5,1.4,0.2]])
# Out:
# array([[8.98656962e-01, 1.01341961e-01, 1.07683291e-06]])
